# %% [markdown]
# ## example

# %%
from read_h import importCSV

filename = "misionlapaz_6.csv"
series_id = 42293
value_column = "Altura Horaria (m)"
head_skip_lines = 5

df = importCSV(filename=filename, series_id=series_id, value_column=value_column, head_skip_lines=head_skip_lines, plot=True)
# Out:
# /home/jbianchi/Documents/pilcomayo/read_h.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Fecha"].fillna(method="ffill", inplace=True)
# /home/jbianchi/Documents/pilcomayo/read_h.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data["Fecha"].fillna(method="ffill", inplace=True)

# %%
df
# Out:
#                                 Fecha      Hora  valor  series_id     tipo
# timestart
# 2025-08-01 00:00:00-03:00  01-08-2025  00:00:00   2.78      42293  puntual
# 2025-08-01 01:00:00-03:00  01-08-2025  01:00:00   2.77      42293  puntual
# 2025-08-01 02:00:00-03:00  01-08-2025  02:00:00   2.78      42293  puntual
# 2025-08-01 03:00:00-03:00  01-08-2025  03:00:00   2.78      42293  puntual
# 2025-08-01 04:00:00-03:00  01-08-2025  04:00:00   2.77      42293  puntual
# ...                               ...       ...    ...        ...      ...
# 2025-08-28 08:00:00-03:00  28-08-2025  08:00:00   2.73      42293  puntual
# 2025-08-28 09:00:00-03:00  28-08-2025  09:00:00   2.74      42293  puntual
# 2025-08-28 10:00:00-03:00  28-08-2025  10:00:00   2.74      42293  puntual
# 2025-08-28 11:00:00-03:00  28-08-2025  11:00:00   2.73      42293  puntual
# 2025-08-28 12:00:00-03:00  28-08-2025  12:00:00   2.71      42293  puntual
#
# [656 rows x 5 columns]

# %%
from a5client import client
client.createObservaciones(df, series_id=series_id)
